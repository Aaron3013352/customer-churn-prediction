# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaron3013352/customer-churn-prediction/blob/main/01_sql_extract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SQL-based Feature Extraction (SQLite)
#
# This notebook simulates a production-style data workflow using SQL.
# Raw Telco churn data is loaded into a SQLite database, queried for
# business insights, and transformed into a clean, model-ready dataset.

# %%
import pandas as pd
import sqlite3
from pathlib import Path
